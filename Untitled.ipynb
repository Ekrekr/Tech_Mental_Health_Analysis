# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

from sklearn.preprocessing import OneHotEncoder

# %%
healthData = pd.read_csv("mental_health_in_tech.csv")

# %%
healthData.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             Jun-25
# 2                                             Jun-25
# 3                                                NaN
# 4                                             Jun-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...

# %%
healthData.keys()
# Out:
# Index(['Are you self-employed?',
#        'How many employees does your company or organization have?',
#        'Is your employer primarily a tech company/organization?',
#        'Is your primary role within your company related to tech/IT?',
#        'Does your employer provide mental health benefits as part of healthcare coverage?',
#        'Do you know the options for mental health care available under your employer-provided coverage?',
#        'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#        'Does your employer offer resources to learn more about mental health concerns and options for seeking help?',
#        'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#        'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:',
# ...

# %%
healthData.dtypes
# Out:
# Are you self-employed?                                                                                                                                                                int64
# How many employees does your company or organization have?                                                                                                                           object
# Is your employer primarily a tech company/organization?                                                                                                                             float64
# Is your primary role within your company related to tech/IT?                                                                                                                        float64
# Does your employer provide mental health benefits as part of healthcare coverage?                                                                                                    object
# ...

# %%
# Useful to split self employed out from employed by a big companies due to qunaitity of NaNs in the self employed rows.
selfData = healthData[healthData["Are you self-employed?"] == 1.0]
autrData = healthData[healthData["Are you self-employed?"] == 0.0]

# %%
# Data is not very clean, need to clean it.

# Each entry here has the key of the column, and then a list of list where each list within the list
# swaps the first item with the second.
conversions = {}
def performConversions(inpDict, inpData):
    for key, swaps in inpDict.items():
        print(swaps)
        for item in swaps:
            print("Swapping", item[0], "and", item[1], "in", key)
            inpData[key].replace(item[0], item[1], inplace=True)
    return inpDict, inpData

# %%
# Find unique codes in each list.
def findUnique(inpData):
    for column in inpData.keys():
        print(column)
        print(set(inpData[column]), "\n")
# Out:
# Are you self-employed?
# {0}
#
# How many employees does your company or organization have?
# {'100-500', '500-1000', 'Jun-25', '26-100', '01-May', 'More than 1000'}
#
# Is your employer primarily a tech company/organization?
# {0.0, 1.0}
#
# Is your primary role within your company related to tech/IT?
# ...

# %%
# conversions["Are you self-employed?"] = [[1.0, True], [0.0, False]]
# conversions["How many employees does your company or organization have?"] = [["1-5", 1], ["6-25", 6], ["26-100", 26], ["100-500", 100], ["500-100", 500], ["More than 1000", 1000]] 

# conversions, autrData = performConversions(conversions)
# conversions, selfData = performConversions(conversions)

# %%
# Convert to One Hot Encoding.
enc = OneHotEncoder()

# %%
autrData.head(10)
# Out:
#     Are you self-employed?  \
# 0                        0
# 1                        0
# 2                        0
# 4                        0
# 5                        0
# 6                        0
# 7                        0
# 8                        0
# 10                       0
# 11                       0
#
#    How many employees does your company or organization have?  \
# 0                                              26-100
# 1                                              Jun-25
# 2                                              Jun-25
# 4                                              Jun-25
# 5                                      More than 1000
# 6                                              26-100
# 7                                      More than 1000
# 8                                              26-100
# 10                                             26-100
# 11                                            100-500
#
# ...

# %%
enc.fit(autrData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-94a3eaa7f1e5> in <module>
# ----> 1 enc.fit(autrData)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#     425             return self
#     426         else:
# --> 427             self._fit(X, handle_unknown=self.handle_unknown)
#     428             return self
#     429
#
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in _fit(self, X, handle_unknown)
#      59
#      60     def _fit(self, X, handle_unknown='error'):
# ---> 61         X = self._check_X(X)
#      62
#      63         n_samples, n_features = X.shape
#
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in _check_X(self, X)
#      54             if not _get_config()['assume_finite']:
#      55                 if _object_dtype_isnan(X).any():
# ...
